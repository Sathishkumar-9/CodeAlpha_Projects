# %%
# !pip install requests beautifulsoup4 pandas

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://books.toscrape.com/"

# %%
response = requests.get(url)

# %%
print(response.status_code)
# Out:
# 200

# %%
soup = BeautifulSoup(response.text, "html.parser")

# %%
books = soup.find_all("article", class_="product_pod")

# %%
titles = []
prices = []
availability = []
ratings = []
links = []

# %%
for book in books:
    title = book.h3.a["title"]
    price = book.find("p", class_="price_color").text
    stock = book.find("p", class_="instock availability").text.strip()
    rating = book.find("p")["class"][1]
    link = "https://books.toscrape.com/catalogue/" + book.h3.a["href"]

    titles.append(title)
    prices.append(price)
    availability.append(stock)
    ratings.append(rating)
    links.append(link)

# %%
print(titles[:5])
# Out:
# ['A Light in the Attic', 'Tipping the Velvet', 'Soumission', 'Sharp Objects', 'Sapiens: A Brief History of Humankind']

# %%
print(prices[:5])
# Out:
# ['Â£51.77', 'Â£53.74', 'Â£50.10', 'Â£47.82', 'Â£54.23']

# %%
df = pd.DataFrame({
    "Title": titles,
    "Price": prices,
    "Availability": availability,
    "Rating": ratings,
    "Product Link": links
})

# %%
df.head()
# Out:
#                                    Title    Price Availability Rating  \
# 0                   A Light in the Attic  Â£51.77     In stock  Three
# 1                     Tipping the Velvet  Â£53.74     In stock    One
# 2                             Soumission  Â£50.10     In stock    One
# 3                          Sharp Objects  Â£47.82     In stock   Four
# 4  Sapiens: A Brief History of Humankind  Â£54.23     In stock   Five
#
#                                         Product Link
# 0  https://books.toscrape.com/catalogue/catalogue...
# 1  https://books.toscrape.com/catalogue/catalogue...
# 2  https://books.toscrape.com/catalogue/catalogue...
# 3  https://books.toscrape.com/catalogue/catalogue...
# 4  https://books.toscrape.com/catalogue/catalogue...

# %%
df
# Out:
#                                                 Title    Price Availability  \
# 0                                A Light in the Attic  Â£51.77     In stock
# 1                                  Tipping the Velvet  Â£53.74     In stock
# 2                                          Soumission  Â£50.10     In stock
# 3                                       Sharp Objects  Â£47.82     In stock
# 4               Sapiens: A Brief History of Humankind  Â£54.23     In stock
# 5                                     The Requiem Red  Â£22.65     In stock
# 6   The Dirty Little Secrets of Getting Your Dream...  Â£33.34     In stock
# 7   The Coming Woman: A Novel Based on the Life of...  Â£17.93     In stock
# 8   The Boys in the Boat: Nine Americans and Their...  Â£22.60     In stock
# 9                                     The Black Maria  Â£52.15     In stock
# 10     Starving Hearts (Triangular Trade Trilogy, #1)  Â£13.99     In stock
# ...

# %%
df.shape
# Out:
# (20, 5)

# %%
df.columns
# Out:
# Index(['Title', 'Price', 'Availability', 'Rating', 'Product Link'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         20 non-null     object
#  1   Price         20 non-null     object
#  2   Availability  20 non-null     object
#  3   Rating        20 non-null     object
#  4   Product Link  20 non-null     object
# dtypes: object(5)
# memory usage: 932.0+ bytes

# %%
df.to_csv("books_data.csv", index=False)

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\DELL\Alpha

# %%
print("Total Books:", len(df))
# Out:
# Total Books: 20

# %%
df.head(10)
# Out:
#                                                Title    Price Availability  \
# 0                               A Light in the Attic  Â£51.77     In stock
# 1                                 Tipping the Velvet  Â£53.74     In stock
# 2                                         Soumission  Â£50.10     In stock
# 3                                      Sharp Objects  Â£47.82     In stock
# 4              Sapiens: A Brief History of Humankind  Â£54.23     In stock
# 5                                    The Requiem Red  Â£22.65     In stock
# 6  The Dirty Little Secrets of Getting Your Dream...  Â£33.34     In stock
# 7  The Coming Woman: A Novel Based on the Life of...  Â£17.93     In stock
# 8  The Boys in the Boat: Nine Americans and Their...  Â£22.60     In stock
# 9                                    The Black Maria  Â£52.15     In stock
#
#   Rating                                       Product Link
# 0  Three  https://books.toscrape.com/catalogue/catalogue...
# ...

# %%
df["Rating"].value_counts()
# Out:
# Rating
# One      6
# Four     4
# Five     4
# Three    3
# Two      3
# Name: count, dtype: int64

# %%
df["Availability"].value_counts()
# Out:
# Availability
# In stock    20
# Name: count, dtype: int64

# %%
df.describe(include="all")
# Out:
#                        Title    Price Availability Rating  \
# count                     20       20           20     20
# unique                    20       20            1      5
# top     A Light in the Attic  Â£51.77     In stock    One
# freq                       1        1           20      6
#
#                                              Product Link
# count                                                  20
# unique                                                 20
# top     https://books.toscrape.com/catalogue/catalogue...
# freq                                                    1

# %%
This project demonstrates how to perform web scraping using python.
Data was collected from a public website using the requests and BeautifulSoup libraies.
The extracted information was organized into a Pandas Dataframe and saved as a CSV file for further analysis.
This project improved my understanding of HTML structure,data extraction and data handling in python.
